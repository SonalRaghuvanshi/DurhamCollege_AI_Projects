# %%
import pandas as pd
from pycaret.datasets import get_data

df = pd.read_csv('C:\\Durham College AI Algo\\AI Algo\\Final Project\\train.csv')

# %%
from pycaret.classification import *

r2 = setup(df,target='satisfaction')
# Out:
# <style  type="text/css" >
# #T_6ad150a8_41bb_11eb_9447_982cbcec0ad5row5_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_6ad150a8_41bb_11eb_9447_982cbcec0ad5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6ad150a8_41bb_11eb_9447_982cbcec0ad5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6ad150a8_41bb_11eb_9447_982cbcec0ad5row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_6ad150a8_41bb_11eb_9447_982cbcec0ad5row0_col1" class="data row0 col1" >5405</td>
#             </tr>
#             <tr>
#                         <th id="T_6ad150a8_41bb_11eb_9447_982cbcec0ad5level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models(include = ['dt','rf'])
# Out:
# <style  type="text/css" >
#     #T_b467ace4_41bb_11eb_af48_982cbcec0ad5 th {
#           text-align: left;
#     }#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row0_col0,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row0_col3,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row1_col0,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row1_col1,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row1_col2,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row1_col4,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row1_col5,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row1_col6,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row1_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row0_col1,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row0_col2,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row0_col4,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row0_col5,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row0_col6,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row0_col7,#T_b467ace4_41bb_11eb_af48_982cbcec0ad5row1_col3{
# ...

# %%
# Model Training and Validation 
rf = create_model('rf')
# Out:
# <style  type="text/css" >
# #T_de19aa40_41bb_11eb_a8fc_982cbcec0ad5row10_col0,#T_de19aa40_41bb_11eb_a8fc_982cbcec0ad5row10_col1,#T_de19aa40_41bb_11eb_a8fc_982cbcec0ad5row10_col2,#T_de19aa40_41bb_11eb_a8fc_982cbcec0ad5row10_col3,#T_de19aa40_41bb_11eb_a8fc_982cbcec0ad5row10_col4,#T_de19aa40_41bb_11eb_a8fc_982cbcec0ad5row10_col5,#T_de19aa40_41bb_11eb_a8fc_982cbcec0ad5row10_col6{
#             background:  yellow;
#         }</style><table id="T_de19aa40_41bb_11eb_a8fc_982cbcec0ad5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
# save transformation pipeline and model 
save_model(rf, model_name = 'deployment_model')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=['Unnamed: 0'],
#                                        ml_usecase='classification',
#                                        numerical_features=[],
#                                        target='satisfaction',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=N...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
# ...
